# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
# %config IPCompleter.greedy=True

# %%
df1.describe()
# Out:
#                DATE           PRCP           SNWD           SNOW  \
# count  1.172080e+05  117208.000000  117208.000000  117208.000000
# mean   1.956978e+07    -489.543785   -4610.883327   -9781.858363
# std    2.723273e+05    2194.002669    4988.596484    1457.514451
# min    1.900010e+07   -9999.000000   -9999.000000   -9999.000000
# 25%    1.937012e+07       0.000000   -9999.000000   -9999.000000
# 50%    1.960040e+07       0.000000       0.000000   -9999.000000
# 75%    1.980032e+07      14.000000       0.000000   -9999.000000
# max    2.000010e+07    1247.000000    2700.000000     140.000000
#
#                 TMAX           TMIN           WDFG           PGTM  \
# count  117208.000000  117208.000000  117208.000000  117208.000000
# mean        3.150766     -68.517789   -9998.301387   -9998.228602
# std      1135.851895    1096.463087      84.559398      93.482800
# min     -9999.000000   -9999.000000   -9999.000000   -9999.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.rename(columns={'Indicator':'Indicator_id'},inplace=True)

# %%
df.head()
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace=True)

# %%
df.columns
# Out:
# Index(['Indicator_id', 'Publication Status', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.sort_values('Year',ascending =True)
# Out:
#                                          Indicator_id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %%
df.sort_values(['Year','WHO Region'],ascending =True)
# Out:
#                                          Indicator_id Publication Status  \
# 64                  Life expectancy at age 60 (years)          Published
# 149                  Life expectancy at birth (years)          Published
# 151                  Life expectancy at birth (years)          Published
# 155                  Life expectancy at birth (years)          Published
# 158                 Life expectancy at age 60 (years)          Published
# 165                  Life expectancy at birth (years)          Published
# 167                  Life expectancy at birth (years)          Published
# 168                 Life expectancy at age 60 (years)          Published
# 172                 Life expectancy at age 60 (years)          Published
# 177                 Life expectancy at age 60 (years)          Published
# 181                  Life expectancy at birth (years)          Published
# 186                 Life expectancy at age 60 (years)          Published
# ...

# %%
cols = list(df)
cols
# Out:
# ['Indicator_id',
#  'Publication Status',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Country',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
cols.insert(0, cols.pop(cols.index('Country')))

# %%
df = df.loc[:, cols]

# %%
df.head()
# Out:
#                 Country                       Indicator_id Publication Status  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %%
df['WHO Region'].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4656, step=1)

# %%
df.iloc[[11,24,37]]
# Out:
#               Country                       Indicator_id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %%
df.filter(items=[5,12,23,56], axis=0)
# Out:
#                 Country                       Indicator_id Publication Status  \
# 5   Antigua and Barbuda   Life expectancy at birth (years)          Published
# 12              Austria  Life expectancy at age 60 (years)          Published
# 23    Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 56              Finland   Life expectancy at birth (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 5   2000         Americas             High-income    Male             72
# 12  2012           Europe             High-income  Female             25
# 23  2000  Western Pacific             High-income  Female             22
# 56  1990           Europe             High-income  Female             79
#
#     Numeric  Low  High  Comments
# 5      72.0  NaN   NaN       NaN
# 12     25.0  NaN   NaN       NaN
# 23     22.0  NaN   NaN       NaN
# 56     79.0  NaN   NaN       NaN

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
#Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
pd.merge(transactions,users, on='UserID', how='left')
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21      7          2         1       NaN
# 1              2      2011-05-26      3          4         1  Caroline
# 2              3      2011-06-16      3          3         1  Caroline
# 3              4      2012-08-26      1          2         3   Charles
# 4              5      2013-06-06      2          4         1     Pedro
# 5              6      2013-12-23      2          5         6     Pedro
# 6              7      2013-12-30      3          4         1  Caroline
# 7              8      2014-04-24    NaN          2         3       NaN
# 8              9      2015-04-24      7          4         3       NaN
# 9             10      2016-05-08      3          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
#Which transactions have a UserID not in users?

# %%
transactions.query('UserID not in @users.UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
pd.merge(transactions,users, on='UserID', how='inner')
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
# 5              5      2013-06-06      2          4         1     Pedro
# 6              6      2013-12-23      2          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
#Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
pd.merge(transactions,users, on='UserID', how='outer')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
#Determine which sessions occurred on the same day each user registered

# %%
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
#users.query('UserID in @sessions.UserID')
#users.query('@users.Registered == @sessions.SessionDate and @users.UserID == @sessions.UserID')

#users.query('(UserID == @sessions.UserID) & (Registered == @sessions.SessionDate)')
#pd.merge(users,sessions, how='inner', on=[users['UserID','Registered'],sessions['UserID','SessionDate']],validate='one_to_one' )
#KeyError: "['2012-12-21' '2010-08-01' '2012-10-23' '2013-07-17' '2010-11-25'] not in index"
dataframe = pd.merge(sessions,users, on='UserID',how='inner')
dataframe.loc[dataframe['SessionDate']==dataframe['Registered']]
# Out:
#    SessionID SessionDate  UserID     User  Gender  Registered   Cancelled
# 1          2  2010-08-01       2    Pedro    male  2010-08-01  2010-08-08
# 7          9  2013-07-17       4  Brielle  female  2013-07-17         NaN

# %%
#Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
users = pd.DataFrame({'key':np.repeat(1,users.shape[0]),'UserID':users.UserID})
transactions = pd.DataFrame({'key':np.repeat(1,transactions.shape[0]),'ProductID':transactions.ProductID})
pd.merge(users,transactions,on='key')[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          2
# 1        1          4
# 2        1          3
# 3        1          2
# 4        1          4
# 5        1          5
# 6        1          4
# 7        1          2
# 8        1          4
# 9        1          4
# 10       2          2
# 11       2          4
# 12       2          3
# 13       2          2
# 14       2          4
# 15       2          5
# 16       2          4
# 17       2          2
# 18       2          4
# 19       2          4
# 20       3          2
# 21       3          4
# 22       3          3
# 23       3          2
# 24       3          4
# 25       3          5
# 26       3          4
# 27       3          2
# 28       3          4
# 29       3          4
# 30       4          2
# 31       4          4
# 32       4          3
# 33       4          2
# 34       4          4
# 35       4          5
# 36       4          4
# 37       4          2
# 38       4          4
# 39       4          4
# ...

# %%
#Determine how much quantity of each product was purchased by each user
df1 = pd.DataFrame({'key':np.repeat(1,users.shape[0]),'UserID':users.UserID})
df2 = pd.DataFrame({'key':np.repeat(1,transactions.shape[0]),'ProductID':transactions.ProductID})
user_products = pd.merge(df1,df2,on='key')[['UserID','ProductID']]
pd.merge(user_products,transactions,how='left',on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x: pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UserID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-20d497df517c> in <module>()
# ...

# %%
transactions
# Out:
#    ProductID  key
# 0          2    1
# 1          4    1
# 2          3    1
# 3          2    1
# 4          4    1
# 5          5    1
# 6          4    1
# 7          2    1
# 8          4    1
# 9          4    1

# %%
#For each user, get each possible pair of pair transactions (TransactionID1,TransacationID2)
pd.merge(transactions,transactions, on='UserID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UserID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-a2fd79f42145> in <module>()
# ...

# %%
#Join each user to his/her first occuring transaction in the transactions table
pd.merge(users,transactions.groupby('UserID').first().reset_index(),how='left',on='UserID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-faa63d1001ec> in <module>()
#       1 #Join each user to his/her first occuring transaction in the transactions table
# ----> 2 pd.merge(users,transactions.groupby('UserID').first().reset_index(),how='left',on='UserID')
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# E:\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# ...

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
data = pd.merge(users,transactions,how='left',on='UserID')
data
# Out:
#   UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1   Charles    male  2012-12-21         NaN            4.0
# 1      2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      2     Pedro    male  2010-08-01  2010-08-08            6.0
# 3      3  Caroline  female  2012-10-23  2016-06-07            2.0
# 4      3  Caroline  female  2012-10-23  2016-06-07            3.0
# 5      3  Caroline  female  2012-10-23  2016-06-07            7.0
# 6      3  Caroline  female  2012-10-23  2016-06-07           10.0
# 7      4   Brielle  female  2013-07-17         NaN            NaN
# 8      5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2013-12-23        5.0       6.0
# 3      2011-05-26        4.0       1.0
# 4      2011-06-16        3.0       1.0
# 5      2013-12-30        4.0       1.0
# ...

# %%
my_columns = list(data.columns)
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    num_missing = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing)) #count of missing data
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    percent_missing = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# percent missing for column Cancelled: 0.3333333333333333
# percent missing for column TransactionID: 0.2222222222222222
# percent missing for column TransactionDate: 0.2222222222222222
# percent missing for column ProductID: 0.2222222222222222
# percent missing for column Quantity: 0.2222222222222222
